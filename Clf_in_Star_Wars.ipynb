# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
test_data = pd.read_csv('invasion.csv')
test_data
# Out:
#          class  g_reflection  i_reflection       speed  brightness  \
# 0    transport      2.190672      6.716633   62.168208    0.347465
# 1    transport      3.453276      8.995909   62.994707    0.590094
# 2    transport      2.432994      6.938691   62.245807    0.329288
# 3      fighter      6.083763      3.019459   18.474555    0.174738
# 4      fighter     12.876769      2.452950  195.805771    0.150446
# ..         ...           ...           ...         ...         ...
# 495    fighter      9.901731      7.162124   58.095069    0.145065
# 496  transport      3.574132      7.118835   62.928159    0.469670
# 497    fighter      9.186049      4.580781  412.102112    0.108195
# 498    fighter      8.278256      8.353756  268.121561    0.132661
# 499  transport      0.860820      8.014988   62.292486    0.304896
#
#      time_of_observance     volume
# 0                158221  44.932446
# 1                385972  41.568300
# 2                446482  40.123467
# ...

# %%
X_train = test_data.drop(['class'], axis = 1)
y_train = test_data['class']

# %%
clf = DecisionTreeClassifier()

# %%
params = {'max_depth' : range(1,8), 'min_samples_split': range(1,13,2), 'min_samples_leaf': range(2,10,2)}
search_grid = GridSearchCV(clf, params, cv = 5)

# %%
search_grid.fit(X_train, y_train)
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/sklearn/tree/_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/sklearn/tree/_classes.py", line 240, in fit
#     % self.min_samples_split)
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   FitFailedWarning)
# ...

# %%
search_grid.best_params_
# Out:
# {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 3}

# %%
test= pd.read_csv('operative_information.csv')

# %%
test
# Out:
#       g_reflection  i_reflection       speed  brightness  time_of_observance  \
# 0         7.516543      3.916691  513.954279    0.177247              105908
# 1         4.322988      6.967689   63.752970    0.545922              277855
# 2         4.595724      9.098297   62.233948    0.389201              160662
# 3         2.689675      7.964869   62.475495    0.541081              162092
# 4         8.075576      5.169719  336.441261    0.174757              466853
# ...            ...           ...         ...         ...                 ...
# 1495     11.755466      5.583147  325.069957    0.170644              388400
# 1496     12.220137      4.023177  439.975574    0.163958              195305
# 1497      1.611053      7.864930   65.025106    0.430021              307856
# 1498      7.114131      5.532188  391.178342    0.150117               51590
# 1499      3.804275      8.038047   62.345396    0.564630               97284
#
#          volume
# 0     13.267224
# ...

# %%
best_tree =  DecisionTreeClassifier(max_depth = 2, min_samples_leaf = 2, min_samples_split = 3)
best_tree.fit(X_train, y_train)
y_pred_test = best_tree.predict(test)

# %%
pd.Series(y_pred_test).value_counts()
# Out:
# fighter      675
# transport    595
# cruiser      230
# dtype: int64
